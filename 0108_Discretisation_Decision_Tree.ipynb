# %%
from sklearn import datasets
import pandas as pd


# Convert the dataset to dataframe

iris = datasets.load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

df = pd.DataFrame(X, columns = feature_names)
df['target'] = y

# %%
predictors = [i for i in feature_names if i not in ['target']]

X = df[predictors]
y = df[['target']]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import numpy as np
from sklearn import preprocessing



a=4
b=10


values = []
X_discretized = pd.DataFrame()
label = preprocessing.LabelEncoder()


for feature in feature_names :
  for i in range(a,b+1):
    #model = DecisionTreeClassifier(criterion='gini', max_features = None, max_leaf_nodes= i)
    model = DecisionTreeClassifier(criterion='gini', max_features = None)
    model = cross_val_score(model, X[[feature]], y, cv=5, scoring='accuracy', n_jobs =-1)
    values.append(np.mean(model)) # Add of the score for each iteration
  model = DecisionTreeClassifier(criterion='gini', max_features = None, 
                                   max_leaf_nodes= values.index(max(values))) # Building of decision tree with the value which have the best accuracy
  model.fit(X[[feature]], y)
  X_discretized[feature] = label.fit_transform(model.predict_proba(X[[feature]])[:,1]) # Change the probability to label with LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bn/3fzk51790p77cl864k6kblr80000gn/T/ipykernel_56316/412132571.py in <module>
#      24   model = DecisionTreeClassifier(criterion='gini', max_features = None,
#      25                                    max_leaf_nodes= values.index(max(values))) # Building of decision tree with the value which have the best accuracy
# ---> 26   model.fit(X[[feature]], y)
#      27   X_discretized[feature] = label.fit_transform(model.predict_proba(X[[feature]])[:,1]) # Change the probability to label with LabelEncoder
#
# ~/opt/anaconda3/envs/py11/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~/opt/anaconda3/envs/py11/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     292                              "%r" % max_leaf_nodes)
#     293         if -1 < max_leaf_nodes < 2:
# --> 294             raise ValueError(("max_leaf_nodes {0} must be either None "
#     295                               "or larger than 1").format(max_leaf_nodes))
#     296
#
# ValueError: max_leaf_nodes 0 must be either None or larger than 1

# %%
X_discretized.sample(10)

# %%
for i in predictors :
  print(X_discretized[i].value_counts())

# %%
X = X_discretized

# %%
model = DecisionTreeClassifier()
scores = cross_val_score(model, X, y, cv=5, scoring='accuracy', n_jobs =-1)
np.mean(scores)

# %%
X = iris.data

# %%
model = DecisionTreeClassifier()
scores = cross_val_score(model, X, y, cv=5, scoring='accuracy', n_jobs =-1)
np.mean(scores)
